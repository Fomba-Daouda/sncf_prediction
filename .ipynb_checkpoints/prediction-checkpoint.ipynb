# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from statsmodels.tsa.statespace.sarimax import SARIMAX
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split

# %%
X = pd.read_csv("Data/train_f_x.csv")
y =  pd.read_csv("Data/y_train_sncf.csv")
final_test_data = pd.read_csv("Data/test_f_x_THurtzP.csv")

# %%
df= X[['date','station','job', 'ferie', 'vacances']]
df['y'] = y['y']

# %%
df = df.set_index('date')

# %%
# Exploration des données
df.describe()
# Out:
#                 job         ferie      vacances             y
# count  1.229863e+06  1.229863e+06  1.229863e+06  1.229863e+06
# mean   7.171587e-01  2.986105e-02  3.395712e-01  3.930904e+03
# std    4.503801e-01  1.702040e-01  4.735639e-01  9.683394e+03
# min    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 25%    0.000000e+00  0.000000e+00  0.000000e+00  2.180000e+02
# 50%    1.000000e+00  0.000000e+00  0.000000e+00  1.108000e+03
# 75%    1.000000e+00  0.000000e+00  1.000000e+00  4.249000e+03
# max    1.000000e+00  1.000000e+00  1.000000e+00  2.084090e+05

# %%
# Visualisation de la distribution de y
sns.histplot(df['y'], kde=True)
plt.title('Distribution de y')
plt.show()

# %%
# Encodage des variables catégorielles
encoder = LabelEncoder()
df['station'] = encoder.fit_transform(df['station'])

# Vérification des corrélations
correlation_matrix = df.corr()
sns.heatmap(correlation_matrix, annot=True)
plt.title('Matrice de corrélation')
plt.show()

# %%
# Encodage des variables catégorielles
encoder = LabelEncoder()
df['station'] = encoder.fit_transform(df['station'])

# Vérification des corrélations
correlation_matrix = df.corr()
sns.heatmap(correlation_matrix, annot=True)
plt.title('Matrice de corrélation')
plt.show()

# %%
# Préparation des données pour le modèle SARIMAX
train, test = train_test_split(df, test_size=0.2, shuffle=False)

# Définition et ajustement du modèle SARIMAX
exog_train = train[['station', 'job', 'ferie', 'vacances']]
exog_test = test[['station', 'job', 'ferie', 'vacances']]

# %%
model = SARIMAX(train['y'], exog=exog_train, order=(1, 1, 1), seasonal_order=(1, 1, 1, 12))
model_fit = model.fit(disp = False)

# Prédiction
predictions = model_fit.predict(start = len(train), end = len(train) + len(test) - 1, exog = exog_test)

# Visualisation des prédictions
plt.plot(train.index, train['y'], label='Entraînement')
plt.plot(test.index, test['y'], label='Test')
plt.plot(test.index, predictions, label='Prédictions')
plt.legend()
plt.title('Prédictions avec SARIMAX')
plt.show()

model_fit.summary()
# Out:
# /Users/daoudafomba/anaconda3/lib/python3.11/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /Users/daoudafomba/anaconda3/lib/python3.11/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it is not monotonic and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /Users/daoudafomba/anaconda3/lib/python3.11/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /Users/daoudafomba/anaconda3/lib/python3.11/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it is not monotonic and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
